# %%
import polars as pl


df = pl.read_parquet("feature_repo/data/driver_stats.parquet")
df
# df.filter(pl.col("driver_id").eq(1001)).sort("event_timestamp", descending=True)

# %%
from feast.data_source import DataSource

DataSource.__subclasses__()

# %%
from feast.base_feature_view import BaseFeatureView

BaseFeatureView.__subclasses__()
